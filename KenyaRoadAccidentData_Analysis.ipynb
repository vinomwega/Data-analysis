# %%
import pandas as pd

# %%
file_path = r"C:\Users\omweg\Desktop\Data Analysis\kenya-accidents-database1.csv"

accidents_data = pd.read_csv(file_path)

# %%
accidents_data.head()
# Out:
#   TIME 24 HOURS BASE/SUB BASE   COUNTY                  ROAD  \
# 0           745        KISUMU   KISUMU         NAIROBI-BUSIA
# 1          1430         NAROK    NAROK             NAROK-MAU
# 2          1515      LONDIANI  KERICHO        KERICHO-NAKURU
# 3          1600      KIMILILI  BUNGOMA       BOKOLI-KIMILILI
# 4          1747        NAKURU   NAKURU  PIPELINE ELEMENTAITA
#
#               PLACE                     MV INVOLVED  \
# 0  KASAGAM FLY OVER  KBS 163T/ZD 9531 AXIOR TRAILER
# 1        NAROK TOWN              KBS 518A HONDA CRV
# 2       JUBERT AREA             KTCB 472K JOHN DEER
# 3       BITUYU AREA         KBW 374M TOYOTA TOWNACE
# 4     PIPELINE AREA      KMDQ 433R DAYAN & KAR 843W
#
#                               BRIEF ACCIDENT DETAILS NAME OF VICTIM GENDER  \
# 0  THE VEHICLE LOST CONTROL AND HIT BARRIER LANDI...        UNKNOWN      F
# 1                THE VEHICLE KNOCKED DOWN THE VICTIM        UNKNOWN      M
# ...

# %%
# view the data metrics
accidents_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TIME 24 HOURS           737 non-null    object
#  1   BASE/SUB BASE           738 non-null    object
#  2   COUNTY                  739 non-null    object
#  3   ROAD                    737 non-null    object
#  4   PLACE                   734 non-null    object
#  5   MV INVOLVED             740 non-null    object
#  6   BRIEF ACCIDENT DETAILS  740 non-null    object
#  7   NAME OF VICTIM          740 non-null    object
#  8   GENDER                  740 non-null    object
#  9   AGE                     739 non-null    object
#  10  CAUSE CODE              718 non-null    float64
#  11  VICTIM                  740 non-null    object
#  12  NO.                     736 non-null    float64
#  13  Date DD/MM/YYYY         740 non-null    object
# ...

# %%
accidents_data.describe()
# Out:
#        CAUSE CODE         NO.
# count  718.000000  736.000000
# mean    47.682451    1.199728
# std     33.091682    1.078951
# min      4.000000    1.000000
# 25%     19.250000    1.000000
# 50%     37.000000    1.000000
# 75%     76.000000    1.000000
# max     99.000000   18.000000

# %% [markdown]
# Data Cleaning

# %%
accident= accidents_data
accident
# Out:
#     TIME 24 HOURS  BASE/SUB BASE     COUNTY                  ROAD  \
# 0             745         KISUMU     KISUMU         NAIROBI-BUSIA
# 1            1430          NAROK      NAROK             NAROK-MAU
# 2            1515       LONDIANI    KERICHO        KERICHO-NAKURU
# 3            1600       KIMILILI    BUNGOMA       BOKOLI-KIMILILI
# 4            1747         NAKURU     NAKURU  PIPELINE ELEMENTAITA
# ..            ...            ...        ...                   ...
# 735          1730          KURIA     MIGORI      NTIMARU-KEHANCHA
# 736          1930         SAGANA  KIRINYAGA        KENOL-MAKUTANO
# 737          2145  DTEO KASARANI    NAIROBI              THIKA RD
# 738          2039       KANGUNDO    MAKUENI      NAIROBI-KANGUNDO
# 739           139  DTEO DAGORETI    NAIROBI           WAIYAKI WAY
#
#                           PLACE                                MV INVOLVED  \
# 0              KASAGAM FLY OVER             KBS 163T/ZD 9531 AXIOR TRAILER
# ...

# %%
# Drop unnecessary columns
accident= accidents_data.drop(['Unnamed: 14'], axis=1)

# Change name of column
accident_df = accident.rename(columns={'Date DD/MM/YYYY': 'Date'})
accident_df_1 = accident_df
'''
# Change 'Date' column to string
accident_df_1["Date"] = accident_df_1["Date"].astype(str)

def fix_missing_year(date):
    if pd.isnull(date) or date.year < 2000:  # Identify missing or incorrect years
        return pd.to_datetime(date.strftime("%d%m") + "2017", format="%d%m%Y", errors="coerce")
    return date

# Apply the function to fix missing years
accident_df_1["Date"] = accident_df_1["Date"].apply(fix_missing_year)

# Convert to final datetime format %d%m%Y
accident_df_1["Date"] =  pd.to_datetime(accident_df_1.Date, format = "%d/%m/%Y")

# Function to reformat dates not in 2017
def reformat_non_2017_dates(date):
    if pd.notna(date) and date != 2017:
        return date.strftime("%d%m")  # Convert to day + month format
    return date  # Keep 2017 dates unchanged

# Apply transformation
accident_df["Date"] = accident_df["Date"].apply(reformat_non_2017_dates)

# Convert 'Date' column to datetime format, coercing errors
accident_df_1["Date"] = pd.to_datetime(accident_df["Date"], errors="coerce", dayfirst=True)



# Apply transformation
accident_df["Date"] = accident_df["Date"].apply(reformat_non_2017_dates)

# Convert back to datetime after modification
def fix_missing_year(date):
    if isinstance(date, str):  # Check if date is a string
        return pd.to_datetime(date + "2017", format="%d%m%Y", errors="coerce")
    return date  # Keep existing datetime values

# Apply the function to fix missing years
accident_df["Date"] = accident_df["Date"].apply(fix_missing_year)

# Convert to final datetime format %d%m%Y
accident_df["Date"] = accident_df["Date"].dt.strftime("%d%m%Y")
'''
# Out:
# '\n# Change \'Date\' column to string\naccident_df_1["Date"] = accident_df_1["Date"].astype(str)\n\ndef fix_missing_year(date):\n    if pd.isnull(date) or date.year < 2000:  # Identify missing or incorrect years\n        return pd.to_datetime(date.strftime("%d%m") + "2017", format="%d%m%Y", errors="coerce")\n    return date\n\n# Apply the function to fix missing years\naccident_df_1["Date"] = accident_df_1["Date"].apply(fix_missing_year)\n\n# Convert to final datetime format %d%m%Y\naccident_df_1["Date"] =  pd.to_datetime(accident_df_1.Date, format = "%d/%m/%Y")\n\n# Function to reformat dates not in 2017\ndef reformat_non_2017_dates(date):\n    if pd.notna(date) and date != 2017:\n        return date.strftime("%d%m")  # Convert to day + month format\n    return date  # Keep 2017 dates unchanged\n\n# Apply transformation\naccident_df["Date"] = accident_df["Date"].apply(reformat_non_2017_dates)\n\n# Convert \'Date\' column to datetime format, coercing errors\naccident_df_1["Date"] = p
# ...

# %%
# Add the year 2017 to the Date column
accident_df_1['Date'] = accident_df_1['Date'].apply(lambda x: f"{x}/2017")

# Convert the Date column to datetime format
accident_df_1['Date'] = pd.to_datetime(accident_df_1['Date'], format='%d/%m/%Y', errors='coerce')

# Display the updated dataframe
accident_df_1.head()
# Out:
#   TIME 24 HOURS BASE/SUB BASE   COUNTY                  ROAD  \
# 0           745        KISUMU   KISUMU         NAIROBI-BUSIA
# 1          1430         NAROK    NAROK             NAROK-MAU
# 2          1515      LONDIANI  KERICHO        KERICHO-NAKURU
# 3          1600      KIMILILI  BUNGOMA       BOKOLI-KIMILILI
# 4          1747        NAKURU   NAKURU  PIPELINE ELEMENTAITA
#
#               PLACE                     MV INVOLVED  \
# 0  KASAGAM FLY OVER  KBS 163T/ZD 9531 AXIOR TRAILER
# 1        NAROK TOWN              KBS 518A HONDA CRV
# 2       JUBERT AREA             KTCB 472K JOHN DEER
# 3       BITUYU AREA         KBW 374M TOYOTA TOWNACE
# 4     PIPELINE AREA      KMDQ 433R DAYAN & KAR 843W
#
#                               BRIEF ACCIDENT DETAILS NAME OF VICTIM GENDER  \
# 0  THE VEHICLE LOST CONTROL AND HIT BARRIER LANDI...        UNKNOWN      F
# 1                THE VEHICLE KNOCKED DOWN THE VICTIM        UNKNOWN      M
# ...

# %%
# Fill missing dates by appending the year 2017
accident_df_1["Date"] = accident_df_1["Date"] .fillna(pd.to_datetime("2017", format="%Y"))
accident_df_1.sample(15)
# Out:
#     TIME 24 HOURS BASE/SUB BASE        COUNTY                  ROAD  \
# 559          1955         MATUU      MACHAKOS           MATUU-THIKA
# 203          1150      NAROMORU         NYERI    NYERI NANYUKI ROAD
# 485          2230        TIGONI        KIAMBU    LIMURU KIAMBU ROAD
# 733           930       MOGOTIO       BARINGO     EMINING-OTERIT RD
# 72            900    ATHI RIVER      MACHAKOS  NAIROBI MOMBASA ROAD
# 366          2345       GARISSA       GARISSA        GARISSA MWINGI
# 364          1900          LARI        KIAMBU      NAIROBI NAIVASHA
# 385           600        KAYOLE       NAIROBI         KANGUNDO ROAD
# 342          1930        VIHIGA        VIHIGA    CHAVAKALI KAPSABET
# 392          1000        KABRAS      KAKAMEGA       KAKAMEGA-WEBUYE
# 708           300   MTITO-ANDEI  TAITA-TAVETA       NAIROBI-MOMBASA
# 129          2000         AHERO        KISUMU           AHERO AWASI
# 51           1330      BURUBURU       NAIROBI           BARAKA ROAD
# ...

# %%
accident_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TIME 24 HOURS           737 non-null    object
#  1   BASE/SUB BASE           738 non-null    object
#  2   COUNTY                  739 non-null    object
#  3   ROAD                    737 non-null    object
#  4   PLACE                   734 non-null    object
#  5   MV INVOLVED             740 non-null    object
#  6   BRIEF ACCIDENT DETAILS  740 non-null    object
#  7   NAME OF VICTIM          740 non-null    object
#  8   GENDER                  740 non-null    object
#  9   AGE                     739 non-null    object
#  10  CAUSE CODE              718 non-null    float64
#  11  VICTIM                  740 non-null    object
#  12  NO.                     736 non-null    float64
#  13  Date                    740 non-null    object
# ...

# %%
accident_df_1
# Out:
#     TIME 24 HOURS  BASE/SUB BASE     COUNTY                  ROAD  \
# 0             745         KISUMU     KISUMU         NAIROBI-BUSIA
# 1            1430          NAROK      NAROK             NAROK-MAU
# 2            1515       LONDIANI    KERICHO        KERICHO-NAKURU
# 3            1600       KIMILILI    BUNGOMA       BOKOLI-KIMILILI
# 4            1747         NAKURU     NAKURU  PIPELINE ELEMENTAITA
# ..            ...            ...        ...                   ...
# 735          1730          KURIA     MIGORI      NTIMARU-KEHANCHA
# 736          1930         SAGANA  KIRINYAGA        KENOL-MAKUTANO
# 737          2145  DTEO KASARANI    NAIROBI              THIKA RD
# 738          2039       KANGUNDO    MAKUENI      NAIROBI-KANGUNDO
# 739           139  DTEO DAGORETI    NAIROBI           WAIYAKI WAY
#
#                           PLACE                                MV INVOLVED  \
# 0              KASAGAM FLY OVER             KBS 163T/ZD 9531 AXIOR TRAILER
# ...

# %%
accident_df.sample(15)
# Out:
#     TIME 24 HOURS BASE/SUB BASE    COUNTY                      ROAD  \
# 722           800      NAIVASHA    NAKURU         NAIVASHA KINANGOP
# 230          1730         BUSIA     BUSIA             BUTULA-MUMIAS
# 434          1100        MALABA   BUNGOMA            BUNGOMA-MALABA
# 211           440      KILIMANI   NAIROBI                NGONG ROAD
# 299          1900        NAKURU    NAKURU            NAKURU-NAIROBI
# 594          1600       BARINGO   BARINGO  TALAI KAPTUM MURRAM ROAD
# 262          2140         MATUU  MACHAKOS              MATUU-MWINGI
# 625       1730HRS     MAKONGENI   NAIROBI                    LADHIS
# 275           930        OYUGIS  HOMA BAY             OYUGIS-KISUMU
# 542          1730       STAREHE   NAIROBI        THIKA SUPERHIGHWAY
# 189           930   MTITO ANDEI   MAKUENI           MOMBASA NAIROBI
# 356          2030      KAPSABET     NANDI          ELDORET KAPSABET
# 265          1900          SUBA   HOMABAY             MBITA-HOMABAY
# ...

# %%
# Drop unnecessary columns
accidents= accidents_data.drop(['Unnamed: 14'], axis=1)

# Change name of column
accidents = accidents.rename(columns={'Date DD/MM/YYYY': 'Date'})

# Change date column to datetime
accidents['Date'] = pd.to_datetime(accidents['Date'], format='%d/%m/%Y')
# Add year to date column
accidents['Date'] = accidents_data['Date'].fillna(pd.to_datetime(2017, format='%Y'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 8
#       5 accidents = accidents.rename(columns={'Date DD/MM/YYYY': 'Date'})
#       7 # Change date column to datetime
# ----> 8 accidents['Date'] = pd.to_datetime(accidents['Date'], format='%d/%m/%Y')
#       9 # Add year to date column
#      10 accidents['Date'] = accidents_data['Date'].fillna(pd.to_datetime(2017, format='%Y'))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
#view datset
accidents.sample(5)
# Out:
#     TIME 24 HOURS BASE/SUB BASE   COUNTY                 ROAD  \
# 155          1320          LARI   KIAMBU     NAIROBI-NAIVASHA
# 43           1000       TARAKWA   NAKURU       ELDORET-NAKURU
# 117            30       MURANGA  MURANGA      MURANGA KANGEMA
# 370            30      EMBAKASI  NAIROBI         MOMBASA ROAD
# 284          1130     KENDU BAY  HOMABAY  KENDU BAY TOWN SHIP
#
#                          PLACE  \
# 155              KIMENDE STAGE
# 43                 BAYETE AREA
# 117               ST MARY AREA
# 370           IMARA DAIMA AREA
# 284  KENDU BAY/OYUGIS JUNCTION
#
#                                            MV INVOLVED  \
# 155                        KBL 976B MATATU (2NK SACCO)
# 43                     KBC 234C/ZA 7408 ACTROS TRAILER
# 117               KAD 056H N/SUNNY & KMCK 872N JIALING
# 370                                   KBS 702E V/WAGEN
# 284  KCA 220R M/TIPPER & PEDESTRIAN & KBX 265H N/SA...
#
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TIME 24 HOURS           737 non-null    object
#  1   BASE/SUB BASE           738 non-null    object
#  2   COUNTY                  739 non-null    object
#  3   ROAD                    737 non-null    object
#  4   PLACE                   734 non-null    object
#  5   MV INVOLVED             740 non-null    object
#  6   BRIEF ACCIDENT DETAILS  740 non-null    object
#  7   NAME OF VICTIM          740 non-null    object
#  8   GENDER                  740 non-null    object
#  9   AGE                     739 non-null    object
#  10  CAUSE CODE              718 non-null    float64
#  11  VICTIM                  740 non-null    object
#  12  NO.                     736 non-null    float64
#  13  Date DD/MM/YYYY         740 non-null    object
# ...

# %%
accidents.head()
# Out:
#   TIME 24 HOURS BASE/SUB BASE   COUNTY                  ROAD  \
# 0           745        KISUMU   KISUMU         NAIROBI-BUSIA
# 1          1430         NAROK    NAROK             NAROK-MAU
# 2          1515      LONDIANI  KERICHO        KERICHO-NAKURU
# 3          1600      KIMILILI  BUNGOMA       BOKOLI-KIMILILI
# 4          1747        NAKURU   NAKURU  PIPELINE ELEMENTAITA
#
#               PLACE                     MV INVOLVED  \
# 0  KASAGAM FLY OVER  KBS 163T/ZD 9531 AXIOR TRAILER
# 1        NAROK TOWN              KBS 518A HONDA CRV
# 2       JUBERT AREA             KTCB 472K JOHN DEER
# 3       BITUYU AREA         KBW 374M TOYOTA TOWNACE
# 4     PIPELINE AREA      KMDQ 433R DAYAN & KAR 843W
#
#                               BRIEF ACCIDENT DETAILS NAME OF VICTIM GENDER  \
# 0  THE VEHICLE LOST CONTROL AND HIT BARRIER LANDI...        UNKNOWN      F
# 1                THE VEHICLE KNOCKED DOWN THE VICTIM        UNKNOWN      M
# ...

# %%
accident.sample(15)
# Out:
#     TIME 24 HOURS  BASE/SUB BASE      COUNTY                         ROAD  \
# 618         NAROK            NaN       NAROK                 NAROK- BOMET
# 736          1930         SAGANA   KIRINYAGA               KENOL-MAKUTANO
# 123          1200     KAPENGURIA  WEST POKOT         MAKUTANO KITALE ROAD
# 714          1230         SALAMA     MAKUENI              NAIROBI-MOMBASA
# 312          1520          KISII       KISII               KISII-KILGORIS
# 715          1230         VIHIGA      VIHIGA              KISUMU-KAKAMEGA
# 19           1730          MATUU    MACHAKOS                KANYONYO-EMBU
# 204          1930       KISERIAN     KAJIADO              KISERIAN MAGADI
# 165          1700         MUMIAS    KAKAMEGA              MUMIAS EBUYANGU
# 590          2330         KIKUYU      KIAMBU            NAIVASHA -NAIROBI
# 515          2140        KISIUMU      KISUMU              KISUMU- NAIROBI
# 5            1830  ONGATA RONGAI     KAJIADO                  MAGADI ROAD
# ...

# %%
accidents_data.sample(15)
# Out:
#     TIME 24 HOURS BASE/SUB BASE       COUNTY  \
# 518           600  DTEO STAREHE      NAIROBI
# 93           2210     DAGORETTI      NAIROBI
# 224          2300        MAGUMU    NYANDARUA
# 661          2120       MAKINDU      MAKUENI
# 563          1330         NYERI        NYERI
# 185           830        GIGIRI      NAIROBI
# 176          2300         SOTIK        BOMET
# 670           330      MACHAKOS     MACHAKOS
# 342          1930        VIHIGA       VIHIGA
# 318           700        KITALE   TRAN NZOIA
# 632          1830       ELDORET  UASIN GISHU
# 70           1400         BONDO        SIAYA
# 48           1200       GARISSA      GARISSA
# 522          1700        BUTERE       KISUMU
# 693          1030        AWENDO       MIGORI
#
#                                   ROAD                      PLACE  \
# 518                 THIKA SUPERHIGHWAY         NEAR JUBILEE HOUSE
# 93                         WAIYAKI WAY            KANGEMI FLYOVER
# ...
